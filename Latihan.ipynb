# %%
from obspy import read
st = read()  # load example seismogram
st.filter(type='highpass', freq=3.0)
st = st.select(component='Z')
st.plot()

# %%
pip install obspy
# Out:
# Collecting obspy
#   Downloading obspy-1.4.0-cp39-cp39-macosx_10_9_x86_64.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.7 in /opt/miniconda3/lib/python3.9/site-packages (from obspy) (1.8.0)
# Requirement already satisfied: matplotlib>=3.3 in /opt/miniconda3/lib/python3.9/site-packages (from obspy) (3.5.1)
# Requirement already satisfied: setuptools in /opt/miniconda3/lib/python3.9/site-packages (from obspy) (61.2.0)
# Requirement already satisfied: decorator in /opt/miniconda3/lib/python3.9/site-packages (from obspy) (5.1.1)
# Requirement already satisfied: numpy>=1.20 in /opt/miniconda3/lib/python3.9/site-packages (from obspy) (1.22.3)
# Requirement already satisfied: sqlalchemy in /opt/miniconda3/lib/python3.9/site-packages (from obspy) (1.4.36)
# Collecting lxml
#   Downloading lxml-4.9.2-cp39-cp39-macosx_10_15_x86_64.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/miniconda3/lib/python3.9/site-packages (from obspy) (2.27.1)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.3->obspy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.3->obspy) (4.33.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.3->obspy) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.3->obspy) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.3->obspy) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.3->obspy) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.3->obspy) (9.1.0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->obspy) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.9/site-packages (from requests->obspy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.9/site-packages (from requests->obspy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/miniconda3/lib/python3.9/site-packages (from requests->obspy) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/miniconda3/lib/python3.9/site-packages (from requests->obspy) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/miniconda3/lib/python3.9/site-packages (from sqlalchemy->obspy) (1.1.2)
# Installing collected packages: lxml, obspy
# Successfully installed lxml-4.9.2 obspy-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import xarray as xr
from affine import Affine

# %%
pip install xarray
# Out:
# Collecting xarray
#   Downloading xarray-2023.5.0-py3-none-any.whl (994 kB)
#      |████████████████████████████████| 994 kB 616 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.21 in /opt/miniconda3/lib/python3.9/site-packages (from xarray) (1.22.3)
# Requirement already satisfied: packaging>=21.3 in /opt/miniconda3/lib/python3.9/site-packages (from xarray) (21.3)
# Requirement already satisfied: pandas>=1.4 in /opt/miniconda3/lib/python3.9/site-packages (from xarray) (1.4.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/miniconda3/lib/python3.9/site-packages (from packaging>=21.3->xarray) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/miniconda3/lib/python3.9/site-packages (from pandas>=1.4->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/lib/python3.9/site-packages (from pandas>=1.4->xarray) (2022.1)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.4->xarray) (1.16.0)
# Installing collected packages: xarray
# Successfully installed xarray-2023.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install affine
# Out:
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: affine
# Successfully installed affine-2.4.0
# Note: you may need to restart the kernel to use updated packages.
